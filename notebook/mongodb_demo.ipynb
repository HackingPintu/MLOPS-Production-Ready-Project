# %%
print("Ok")

# !pip install openpyxl
# Out:
# Ok
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...

# %%
'''
mongodb+srv://rathpintu90:ctTL9C5USW65kx9l@cluster0.gsvix.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
'''

# %%
import pandas as pd

df=pd.read_excel("newmoli.xlsx")
df.head()
# Out:
#    job_id  entity_id             entity_name    date_of_job_post job_title  \
# 0      31          3  SeaTac Municipal Court 2024-04-25 16:02:06   Spanish
# 1      32          3  SeaTac Municipal Court 2024-04-26 17:47:24    Arabic
# 2      34          3  SeaTac Municipal Court 2024-04-25 16:49:18    French
# 3      40          3  SeaTac Municipal Court 2024-04-25 17:24:14    French
# 4      42          3  SeaTac Municipal Court 2024-04-25 17:32:36   Chinese
#
#      application_date  time_difference_hours  time_difference_minutes  \
# 0 2024-04-25 16:02:38                      0                        0
# 1 2024-04-26 17:47:54                      0                        0
# 2 2024-04-25 16:49:29                      0                        0
# 3 2024-04-25 17:24:25                      0                        0
# 4 2024-04-25 17:32:45                      0                        0
#
#    interpreter_id   interpreter_name           interpreter_email  rate  \
# ...

# %%
df.shape
# Out:
# (674, 15)

# %%
df.columns
# Out:
# Index(['job_id', 'entity_id', 'entity_name', 'date_of_job_post', 'job_title',
#        'application_date', 'time_difference_hours', 'time_difference_minutes',
#        'interpreter_id', 'interpreter_name', 'interpreter_email', 'rate',
#        'certification', 'certification_name', 'application_status'],
#       dtype='object')

# %%
data=df.to_dict(orient="records")
data
# Out:
# [{'job_id': 31,
#   'entity_id': 3,
#   'entity_name': 'SeaTac Municipal Court',
#   'date_of_job_post': Timestamp('2024-04-25 16:02:06'),
#   'job_title': 'Spanish',
#   'application_date': Timestamp('2024-04-25 16:02:38'),
#   'time_difference_hours': 0,
#   'time_difference_minutes': 0,
#   'interpreter_id': 12,
#   'interpreter_name': 'Hilary Hughes',
#   'interpreter_email': 'hilaryhughes@intercom.cc',
#   'rate': 70,
#   'certification': 2,
#   'certification_name': 'Aoc Certified',
#   'application_status': 1},
#  {'job_id': 32,
#   'entity_id': 3,
#   'entity_name': 'SeaTac Municipal Court',
#   'date_of_job_post': Timestamp('2024-04-26 17:47:24'),
#   'job_title': 'Arabic',
#   'application_date': Timestamp('2024-04-26 17:47:54'),
#   'time_difference_hours': 0,
#   'time_difference_minutes': 0,
#   'interpreter_id': 15,
#   'interpreter_name': 'Masuood Muhammed',
#   'interpreter_email': 'masuoodabas@gmail.com',
#   'rate': 50,
#   'certification': 0,
# ...

# %%
len(data)
# Out:
# 674

# %%
db_name="rate_prediction"
collection_name="rate_data"
connection_url="mongodb+srv://rathpintu90:ctTL9C5USW65kx9l@cluster0.gsvix.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

client=pymongo.MongoClient(connection_url)
data_base=client[db_name]
collection=data_base[collection_name]

rec=collection.insert_many(data)

# %%
records=collection.find()
records

# %%
for i,j in enumerate(records):
    print(f"{i}:{j}")
# Out:
# 0:{'_id': ObjectId('66fe2bf302c0bae86d9ef77f'), 'job_id': 31, 'entity_id': 3, 'entity_name': 'SeaTac Municipal Court', 'date_of_job_post': datetime.datetime(2024, 4, 25, 16, 2, 6), 'job_title': 'Spanish', 'application_date': datetime.datetime(2024, 4, 25, 16, 2, 38), 'time_difference_hours': 0, 'time_difference_minutes': 0, 'interpreter_id': 12, 'interpreter_name': 'Hilary Hughes', 'interpreter_email': 'hilaryhughes@intercom.cc', 'rate': 70, 'certification': 2, 'certification_name': 'Aoc Certified', 'application_status': 1}
# ...

# %%
new_df=pd.DataFrame(list(collection.find()))
new_df.head()
# Out:
#                         _id  job_id  entity_id             entity_name  \
# 0  66fe2bf302c0bae86d9ef77f      31          3  SeaTac Municipal Court
# 1  66fe2bf302c0bae86d9ef780      32          3  SeaTac Municipal Court
# 2  66fe2bf302c0bae86d9ef781      34          3  SeaTac Municipal Court
# 3  66fe2bf302c0bae86d9ef782      40          3  SeaTac Municipal Court
# 4  66fe2bf302c0bae86d9ef783      42          3  SeaTac Municipal Court
#
#      date_of_job_post job_title    application_date  time_difference_hours  \
# 0 2024-04-25 16:02:06   Spanish 2024-04-25 16:02:38                      0
# 1 2024-04-26 17:47:24    Arabic 2024-04-26 17:47:54                      0
# 2 2024-04-25 16:49:18    French 2024-04-25 16:49:29                      0
# 3 2024-04-25 17:24:14    French 2024-04-25 17:24:25                      0
# 4 2024-04-25 17:32:36   Chinese 2024-04-25 17:32:45                      0
#
#    time_difference_minutes  interpreter_id   interpreter_name  \
# ...

# %%
if "_id" in new_df.columns.to_list():
    new_df=new_df.drop(columns=["_id"],axis=1)
    
new_df.head()
# Out:
#    job_id  entity_id             entity_name    date_of_job_post job_title  \
# 0      31          3  SeaTac Municipal Court 2024-04-25 16:02:06   Spanish
# 1      32          3  SeaTac Municipal Court 2024-04-26 17:47:24    Arabic
# 2      34          3  SeaTac Municipal Court 2024-04-25 16:49:18    French
# 3      40          3  SeaTac Municipal Court 2024-04-25 17:24:14    French
# 4      42          3  SeaTac Municipal Court 2024-04-25 17:32:36   Chinese
#
#      application_date  time_difference_hours  time_difference_minutes  \
# 0 2024-04-25 16:02:38                      0                        0
# 1 2024-04-26 17:47:54                      0                        0
# 2 2024-04-25 16:49:29                      0                        0
# 3 2024-04-25 17:24:25                      0                        0
# 4 2024-04-25 17:32:45                      0                        0
#
#    interpreter_id   interpreter_name           interpreter_email  rate  \
# ...
